# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../data/international-airline-passengers.csv")

# %%
df.head()
# Out:
#      Month  Thousand Passengers
# 0  1949-01                  112
# 1  1949-02                  118
# 2  1949-03                  132
# 3  1949-04                  129
# 4  1949-05                  121

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 2 columns):
# Month                  144 non-null object
# Thousand Passengers    144 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 2.3+ KB

# %%
type(df.Month[0])
# Out:
# str

# %% [markdown]
# # month is here is str datatype

# %%
df.Month = pd.to_datetime(df.Month)

# %%
type(df.Month[0])
# Out:
# pandas.tslib.Timestamp

# %%
df.head()
# Out:
#        Month  Thousand Passengers
# 0 1949-01-01                  112
# 1 1949-02-01                  118
# 2 1949-03-01                  132
# 3 1949-04-01                  129
# 4 1949-05-01                  121

# %%
df.set_index(df.Month)
# Out:
#                 Month  Thousand Passengers
# Month
# 1949-01-01 1949-01-01                  112
# 1949-02-01 1949-02-01                  118
# 1949-03-01 1949-03-01                  132
# 1949-04-01 1949-04-01                  129
# 1949-05-01 1949-05-01                  121
# 1949-06-01 1949-06-01                  135
# 1949-07-01 1949-07-01                  148
# 1949-08-01 1949-08-01                  148
# 1949-09-01 1949-09-01                  136
# 1949-10-01 1949-10-01                  119
# 1949-11-01 1949-11-01                  104
# 1949-12-01 1949-12-01                  118
# 1950-01-01 1950-01-01                  115
# 1950-02-01 1950-02-01                  126
# 1950-03-01 1950-03-01                  141
# 1950-04-01 1950-04-01                  135
# 1950-05-01 1950-05-01                  125
# 1950-06-01 1950-06-01                  149
# 1950-07-01 1950-07-01                  170
# 1950-08-01 1950-08-01                  170
# 1950-09-01 1950-09-01                  158
# 1950-10-01 1950-10-01                  133
# 1950-11-01 1950-11-01                  114
# 1950-12-01 1950-12-01                  140
# 1951-01-01 1951-01-01                  145
# 1951-02-01 1951-02-01                  150
# 1951-03-01 1951-03-01                  178
# 1951-04-01 1951-04-01                  163
# 1951-05-01 1951-05-01                  172
# 1951-06-01 1951-06-01                  178
# ...               ...                  ...
# 1958-07-01 1958-07-01                  491
# 1958-08-01 1958-08-01                  505
# 1958-09-01 1958-09-01                  404
# 1958-10-01 1958-10-01                  359
# 1958-11-01 1958-11-01                  310
# 1958-12-01 1958-12-01                  337
# 1959-01-01 1959-01-01                  360
# 1959-02-01 1959-02-01                  342
# 1959-03-01 1959-03-01                  406
# 1959-04-01 1959-04-01                  396
# 1959-05-01 1959-05-01                  420
# 1959-06-01 1959-06-01                  472
# 1959-07-01 1959-07-01                  548
# 1959-08-01 1959-08-01                  559
# 1959-09-01 1959-09-01                  463
# 1959-10-01 1959-10-01                  407
# 1959-11-01 1959-11-01                  362
# 1959-12-01 1959-12-01                  405
# 1960-01-01 1960-01-01                  417
# 1960-02-01 1960-02-01                  391
# 1960-03-01 1960-03-01                  419
# 1960-04-01 1960-04-01                  461
# 1960-05-01 1960-05-01                  472
# 1960-06-01 1960-06-01                  535
# 1960-07-01 1960-07-01                  622
# 1960-08-01 1960-08-01                  606
# 1960-09-01 1960-09-01                  508
# 1960-10-01 1960-10-01                  461
# 1960-11-01 1960-11-01                  390
# 1960-12-01 1960-12-01                  432
#
# [144 rows x 2 columns]

# %%
del df["Month"]

# %%
df.head()
# Out:
#    Thousand Passengers
# 0                  112
# 1                  118
# 2                  132
# 3                  129
# 4                  121

# %%
df.plot(kind = 'hist',x = 'Month', y = 'Thousand Passengers')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\envs\ztdl\lib\site-packages\pandas\indexes\base.py in get_loc(self, key, method, tolerance)
#    2133             try:
# -> 2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4433)()
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4279)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:13742)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:13696)()
#
# KeyError: 'Month'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-46-a9b26780ffb4> in <module>()
# ----> 1 df.plot(kind = 'hist',x = 'Month', y = 'Thousand Passengers')
#
# ~\Anaconda3\envs\ztdl\lib\site-packages\pandas\tools\plotting.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    3772                           fontsize=fontsize, colormap=colormap, table=table,
#    3773                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 3774                           sort_columns=sort_columns, **kwds)
#    3775     __call__.__doc__ = plot_frame.__doc__
#    3776
#
# ~\Anaconda3\envs\ztdl\lib\site-packages\pandas\tools\plotting.py in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2641                  yerr=yerr, xerr=xerr,
#    2642                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 2643                  **kwds)
#    2644
#    2645
#
# ~\Anaconda3\envs\ztdl\lib\site-packages\pandas\tools\plotting.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    2448                 if is_integer(x) and not data.columns.holds_integer():
#    2449                     x = data.columns[x]
# -> 2450                 data = data.set_index(x)
#    2451
#    2452             if y is not None:
#
# ~\Anaconda3\envs\ztdl\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    2915                 names.append(None)
#    2916             else:
# -> 2917                 level = frame[col]._values
#    2918                 names.append(col)
#    2919                 if drop:
#
# ~\Anaconda3\envs\ztdl\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2057             return self._getitem_multilevel(key)
#    2058         else:
# -> 2059             return self._getitem_column(key)
#    2060
#    2061     def _getitem_column(self, key):
#
# ~\Anaconda3\envs\ztdl\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2064         # get column
#    2065         if self.columns.is_unique:
# -> 2066             return self._get_item_cache(key)
#    2067
#    2068         # duplicate columns & possible reduce dimensionality
#
# ~\Anaconda3\envs\ztdl\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    1384         res = cache.get(item)
#    1385         if res is None:
# -> 1386             values = self._data.get(item)
#    1387             res = self._box_item_values(item, values)
#    1388             cache[item] = res
#
# ~\Anaconda3\envs\ztdl\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    3541
#    3542             if not isnull(item):
# -> 3543                 loc = self.items.get_loc(item)
#    3544             else:
#    3545                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# ~\Anaconda3\envs\ztdl\lib\site-packages\pandas\indexes\base.py in get_loc(self, key, method, tolerance)
#    2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
# -> 2136                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2137
#    2138         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4433)()
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4279)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:13742)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:13696)()
#
# KeyError: 'Month'

# %%
df.plot(kind = 'scatter')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-236873c86817> in <module>()
# ----> 1 df.plot(kind = 'scatter')
#
# ~\Anaconda3\envs\ztdl\lib\site-packages\pandas\tools\plotting.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    3772                           fontsize=fontsize, colormap=colormap, table=table,
#    3773                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 3774                           sort_columns=sort_columns, **kwds)
#    3775     __call__.__doc__ = plot_frame.__doc__
#    3776
#
# ~\Anaconda3\envs\ztdl\lib\site-packages\pandas\tools\plotting.py in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2641                  yerr=yerr, xerr=xerr,
#    2642                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 2643                  **kwds)
#    2644
#    2645
#
# ~\Anaconda3\envs\ztdl\lib\site-packages\pandas\tools\plotting.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    2426         if isinstance(data, DataFrame):
#    2427             plot_obj = klass(data, x=x, y=y, subplots=subplots, ax=ax,
# -> 2428                              kind=kind, **kwds)
#    2429         else:
#    2430             raise ValueError("plot kind %r can only be used for data frames"
#
# ~\Anaconda3\envs\ztdl\lib\site-packages\pandas\tools\plotting.py in __init__(self, data, x, y, s, c, **kwargs)
#    1584             # the handling of this argument later
#    1585             s = 20
# -> 1586         super(ScatterPlot, self).__init__(data, x, y, s=s, **kwargs)
#    1587         if is_integer(c) and not self.data.columns.holds_integer():
#    1588             c = self.data.columns[c]
#
# ~\Anaconda3\envs\ztdl\lib\site-packages\pandas\tools\plotting.py in __init__(self, data, x, y, **kwargs)
#    1558         MPLPlot.__init__(self, data, **kwargs)
#    1559         if x is None or y is None:
# -> 1560             raise ValueError(self._kind + ' requires and x and y column')
#    1561         if is_integer(x) and not self.data.columns.holds_integer():
#    1562             x = self.data.columns[x]
#
# ValueError: scatter requires and x and y column
