# %%
from PIL import Image
import numpy as np
import pandas as pd

# %%
img = Image.open('../data/iss.jpg')

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x435 at 0x20C64447F28>

# %%
imgarray = np.asarray(img)

# %%
imgarray
# Out:
# array([[[139, 169, 205],
#         [132, 160, 199],
#         [132, 159, 202],
#         ...,
#         [118, 106, 106],
#         [ 96,  84,  84],
#         [ 65,  51,  51]],
#
#        [[138, 168, 206],
#         [119, 148, 188],
#         [108, 135, 180],
#         ...,
#         [ 32,  20,  20],
#         [ 23,  11,  11],
#         [ 45,  31,  31]],
#
#        [[121, 155, 193],
#         [125, 156, 200],
#         [120, 148, 195],
#         ...,
#         [ 32,  20,  20],
#         [ 38,  26,  26],
#         [ 49,  35,  35]],
#
#        ...,
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
imgarray.shape
# Out:
# (435, 640, 3)

# %%
imgarray.ravel()
# Out:
# array([139, 169, 205, ..., 255, 255, 255], dtype=uint8)

# %%
df = pd.DataFrame(imgarray.ravel())

# %%
df
# Out:
#           0
# 0       139
# 1       169
# 2       205
# 3       132
# 4       160
# 5       199
# 6       132
# 7       159
# 8       202
# 9       135
# 10      159
# 11      207
# 12      131
# 13      155
# 14      201
# 15      132
# 16      157
# 17      198
# 18      130
# 19      160
# 20      198
# 21      122
# 22      156
# 23      193
# 24      124
# 25      162
# 26      201
# 27      120
# 28      161
# 29      207
# ...     ...
# 835170  255
# 835171  255
# 835172  255
# 835173  255
# 835174  255
# 835175  255
# 835176  255
# 835177  255
# 835178  255
# 835179  255
# 835180  255
# 835181  255
# 835182  255
# 835183  255
# 835184  255
# 835185  255
# 835186  255
# 835187  255
# 835188  255
# 835189  255
# 835190  255
# 835191  255
# 835192  255
# 835193  255
# 835194  255
# 835195  255
# 835196  255
# 835197  255
# 835198  255
# 835199  255
#
# [835200 rows x 1 columns]

# %% [markdown]
# # with sound unstructured data

# %%
|
